# %%
# Dependencies
from flask import Flask, render_template, redirect
from flask_pymongo import PyMongo
from bs4 import BeautifulSoup as bs
import requests
from splinter import Browser
import time 
import citipy
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from scipy.stats import linregress
from datetime import date
from tqdm import tqdm

from epa_API_key import epa_api_key

#output_data_file = "output_data/air_quality.csv"

# %%
from datetime import date, timedelta
today = date.today()
date1 = (today - timedelta(days = 90)).strftime('%Y%m%d')
date2 = (today - timedelta(days = 90)).strftime('%Y%m%d')
print(today)
print(date1)
print(date2)
# Out:
# 2020-04-12
# 20200113
# 20200113

# %%
print(epa_api_key)
print()
# Out:
# coppergazelle96

# %%
key = epa_api_key
param_list = [42101, 42401, 44201, 81102, 88101]

# Lat/Long Source: https://www.worldatlas.com/aatlas/infopage/nsewusa.htm

#farthest east
maxlon = -66.9
#farthest west
minlon = -124.7
#farthest south
minlat = 25.1
#farthest north
maxlat = 49.3

query_urlList = []
response_list = []

for param in param_list:
    query_url = f"https://aqs.epa.gov/data/api/dailyData/byBox?email=josephmrafferty@gmail.com&key={key}&param={param}&bdate={date1}&edate={date2}&minlat={minlat}&maxlat={maxlat}&minlon={minlon}&maxlon={maxlon}"
    print(query_url)
    query_urlList.append(query_url)
    response = requests.get(query_url).json()
    response_list.append(response)
    time.sleep(5)

print("-----------------")
print(query_urlList)
# Out:
# https://aqs.epa.gov/data/api/dailyData/byBox?email=josephmrafferty@gmail.com&key=coppergazelle96&param=42101&bdate=20200113&edate=20200113&minlat=25.1&maxlat=49.3&minlon=-124.7&maxlon=-66.9
# https://aqs.epa.gov/data/api/dailyData/byBox?email=josephmrafferty@gmail.com&key=coppergazelle96&param=42401&bdate=20200113&edate=20200113&minlat=25.1&maxlat=49.3&minlon=-124.7&maxlon=-66.9
# https://aqs.epa.gov/data/api/dailyData/byBox?email=josephmrafferty@gmail.com&key=coppergazelle96&param=44201&bdate=20200113&edate=20200113&minlat=25.1&maxlat=49.3&minlon=-124.7&maxlon=-66.9
# https://aqs.epa.gov/data/api/dailyData/byBox?email=josephmrafferty@gmail.com&key=coppergazelle96&param=81102&bdate=20200113&edate=20200113&minlat=25.1&maxlat=49.3&minlon=-124.7&maxlon=-66.9
# https://aqs.epa.gov/data/api/dailyData/byBox?email=josephmrafferty@gmail.com&key=coppergazelle96&param=88101&bdate=20200113&edate=20200113&minlat=25.1&maxlat=49.3&minlon=-124.7&maxlon=-66.9
# -----------------
# ['https://aqs.epa.gov/data/api/dailyData/byBox?email=josephmrafferty@gmail.com&key=coppergazelle96&param=42101&bdate=20200113&edate=20200113&minlat=25.1&maxlat=49.3&minlon=-124.7&maxlon=-66.9', 'https://aqs.epa.gov/data/api/dailyData/byBox?email=josephmrafferty@gmail.com&key=coppergazelle96&param=42401&bdate=20200113&edate=20200113&minlat=25.1&maxlat=49.3&minlon=-124.7&maxlon=-66.9', 'https://aqs.epa.gov/data/api/dailyData/byBox?email=josephmrafferty@gmail.com&key=coppergazelle96&param=44201&bdate=20200113&edate=20200113&minlat=25.1&maxlat=49.3&minlon=-124.7&maxlon=-66.9', 'https://aqs.epa.gov/data/api/dailyData/byBox?email=josephmrafferty@gmail.com&key=coppergazelle96&param=81102&bdate=20200113&edate=20200113&minlat=25.1&maxlat=49.3&minlon=-124.7&maxlon=-66.9', 'https://aqs.epa.gov/data/api/dailyData/byBox?email=josephmrafferty@gmail.com&key=coppergazelle96&param=88101&bdate=20200113&edate=20200113&minlat=25.1&maxlat=49.3&minlon=-124.7&maxlon=-66.9']

# %%
print(response_list[0])
print('-------------')
print(response_list[1])
print('-------------')
print(response_list[2])
print('-------------')
print(response_list[3])
# Out:
# {'Header': [{'status': 'Success', 'request_time': '2020-04-12T14:22:21-04:00', 'url': 'https://aqs.epa.gov/data/api/dailyData/byBox?email=josephmrafferty@gmail.com&key=coppergazelle96&param=42101&bdate=20200113&edate=20200113&minlat=25.1&maxlat=49.3&minlon=-124.7&maxlon=-66.9', 'rows': 134}], 'Data': [{'state_code': '04', 'county_code': '013', 'site_number': '9997', 'parameter_code': '42101', 'poc': 1, 'latitude': 33.503833, 'longitude': -112.095767, 'datum': 'WGS84', 'parameter': 'Carbon monoxide', 'sample_duration': '1 HOUR', 'pollutant_standard': 'CO 1-hour 1971', 'date_local': '2020-01-13', 'units_of_measure': 'Parts per million', 'event_type': 'None', 'observation_count': 24, 'observation_percent': 100.0, 'validity_indicator': 'Y', 'arithmetic_mean': 0.644583, 'first_max_value': 1.591, 'first_max_hour': 7, 'aqi': None, 'method_code': '593', 'method': 'INSTRUMENTAL - Gas Filter Correlation Teledyne API 300 EU', 'local_site_name': 'JLG SUPERSITE', 'site_address': '4530 N 17TH AVENUE', 'state': 'Arizona', 'county': 'Maricopa', 'city': 'Phoenix', 'cbsa_code': '38060', 'cbsa': 'Phoenix-Mesa-Scottsdale, AZ', 'date_of_last_change': '2020-04-09'}, {'state_code': '04', 'county_code': '013', 'site_number': '9997', 'parameter_code': '42101', 'poc': 1, 'latitude': 33.503833, 'longitude': -112.095767, 'datum': 'WGS84', 'parameter': 'Carbon monoxide', 'sample_duration': '8-HR RUN AVG END HOUR', 'pollutant_standard': 'CO 8-hour 1971', 'date_local': '2020-01-13', 'units_of_measure': 'Parts per million', 'event_type': 'None', 'observation_count': 24, 'observation_percent': 100.0, 'validity_indicator': 'Y', 'arithmetic_mean': 0.625, 'first_max_value': 0.9, 'first_max_hour': 0, 'aqi': 10, 'method_code': '593', 'method': 'INSTRUMENTAL - Gas Filter Correlation Teledyne API 300 EU', 'local_site_name': 'JLG SUPERSITE', 'site_address': '4530 N 17TH AVENUE', 'state': 'Arizona', 'county': 'Maricopa', 'city': 'Phoenix', 'cbsa_code': '38060', 'cbsa': 'Phoenix-Mesa-Scottsdale, AZ', 'date_of_last_change': '2020-04-09'}, {'state_code': '05', 'county_code': '119', 'site_number': '0007', 'parameter_code': '42101', 'poc': 2, 'latitude': 34.756189, 'longitude': -92.281296, 'datum': 'WGS84', 'parameter': 'Carbon monoxide', 'sample_duration': '1 HOUR', 'pollutant_standard': 'CO 1-hour 1971', 'date_local': '2020-01-13', 'units_of_measure': 'Parts per million', 'event_type': 'None', 'observation_count': 24, 'observation_percent': 100.0, 'validity_indicator': 'Y', 'arithmetic_mean': 0.329167, 'first_max_value': 0.8, 'first_max_hour': 6, 'aqi': None, 'method_code': '054', 'method': 'INSTRUMENTAL - NONDISPERSIVE INFRARED', 'local_site_name': 'PARR', 'site_address': 'PIKE AVE AT RIVER ROAD', 'state': 'Arkansas', 'county': 'Pulaski', 'city': 'North Little Rock', 'cbsa_code': '30780', 'cbsa': 'Little Rock-North Little Rock-Conway, AR', 'date_of_last_change': '2020-04-06'}, {'state_code': '05', 'county_code': '119', 'site_number': '0007', 'parameter_code': '42101', 'poc': 2, 'latitude': 34.756189, 'longitude': -92.281296, 'datum': 'WGS84', 'parameter': 'Carbon monoxide', 'sample_duration': '8-HR RUN AVG END HOUR', 'pollutant_standard': 'CO 8-hour 1971', 'date_local': '2020-01-13', 'units_of_measure': 'Parts per million', 'event_type': 'None', 'observation_count': 24, 'observation_percent': 100.0, 'validity_indicator': 'Y', 'arithmetic_mean': 0.320833, 'first_max_value': 0.5, 'first_max_hour': 7, 'aqi': 6, 'method_code': '054', 'method': 'INSTRUMENTAL - NONDISPERSIVE INFRARED', 'local_site_name': 'PARR', 'site_address': 'PIKE AVE AT RIVER ROAD', 'state': 'Arkansas', 'county': 'Pulaski', 'city': 'North Little Rock', 'cbsa_code': '30780', 'cbsa': 'Little Rock-North Little Rock-Conway, AR', 'date_of_last_change': '2020-04-06'}, {'state_code': '06', 'county_code': '083', 'site_number': '1025', 'parameter_code': '42101', 'poc': 1, 'latitude': 34.48974, 'longitude': -120.04692, 'datum': 'WGS84', 'parameter': 'Carbon monoxide', 'sample_duration': '1 HOUR', 'pollutant_standar ...
# -------------
# {'Header': [{'status': 'Success', 'request_time': '2020-04-12T14:22:26-04:00', 'url': 'https://aqs.epa.gov/data/api/dailyData/byBox?email=josephmrafferty@gmail.com&key=coppergazelle96&param=42401&bdate=20200113&edate=20200113&minlat=25.1&maxlat=49.3&minlon=-124.7&maxlon=-66.9', 'rows': 678}], 'Data': [{'state_code': '04', 'county_code': '013', 'site_number': '9997', 'parameter_code': '42401', 'poc': 5, 'latitude': 33.503833, 'longitude': -112.095767, 'datum': 'WGS84', 'parameter': 'Sulfur dioxide', 'sample_duration': '5 MINUTE', 'pollutant_standard': None, 'date_local': '2020-01-13', 'units_of_measure': 'Parts per billion', 'event_type': 'None', 'observation_count': 286, 'observation_percent': 99.0, 'validity_indicator': 'Y', 'arithmetic_mean': 1.14965, 'first_max_value': 2.9, 'first_max_hour': 8, 'aqi': None, 'method_code': '600', 'method': 'Instrumental - Ultraviolet Fluorescence API 100 EU', 'local_site_name': 'JLG SUPERSITE', 'site_address': '4530 N 17TH AVENUE', 'state': 'Arizona', 'county': 'Maricopa', 'city': 'Phoenix', 'cbsa_code': '38060', 'cbsa': 'Phoenix-Mesa-Scottsdale, AZ', 'date_of_last_change': '2020-04-09'}, {'state_code': '04', 'county_code': '013', 'site_number': '9997', 'parameter_code': '42401', 'poc': 1, 'latitude': 33.503833, 'longitude': -112.095767, 'datum': 'WGS84', 'parameter': 'Sulfur dioxide', 'sample_duration': '1 HOUR', 'pollutant_standard': 'SO2 Annual 1971', 'date_local': '2020-01-13', 'units_of_measure': 'Parts per billion', 'event_type': 'None', 'observation_count': 22, 'observation_percent': 92.0, 'validity_indicator': 'Y', 'arithmetic_mean': 1.2, 'first_max_value': 2.4, 'first_max_hour': 7, 'aqi': 3, 'method_code': '600', 'method': 'Instrumental - Ultraviolet Fluorescence API 100 EU', 'local_site_name': 'JLG SUPERSITE', 'site_address': '4530 N 17TH AVENUE', 'state': 'Arizona', 'county': 'Maricopa', 'city': 'Phoenix', 'cbsa_code': '38060', 'cbsa': 'Phoenix-Mesa-Scottsdale, AZ', 'date_of_last_change': '2020-04-09'}, {'state_code': '04', 'county_code': '013', 'site_number': '9997', 'parameter_code': '42401', 'poc': 1, 'latitude': 33.503833, 'longitude': -112.095767, 'datum': 'WGS84', 'parameter': 'Sulfur dioxide', 'sample_duration': '1 HOUR', 'pollutant_standard': 'SO2 1-hour 2010', 'date_local': '2020-01-13', 'units_of_measure': 'Parts per billion', 'event_type': 'None', 'observation_count': 22, 'observation_percent': 92.0, 'validity_indicator': 'Y', 'arithmetic_mean': 1.2, 'first_max_value': 2.4, 'first_max_hour': 7, 'aqi': 3, 'method_code': '600', 'method': 'Instrumental - Ultraviolet Fluorescence API 100 EU', 'local_site_name': 'JLG SUPERSITE', 'site_address': '4530 N 17TH AVENUE', 'state': 'Arizona', 'county': 'Maricopa', 'city': 'Phoenix', 'cbsa_code': '38060', 'cbsa': 'Phoenix-Mesa-Scottsdale, AZ', 'date_of_last_change': '2020-04-09'}, {'state_code': '04', 'county_code': '013', 'site_number': '9997', 'parameter_code': '42401', 'poc': 1, 'latitude': 33.503833, 'longitude': -112.095767, 'datum': 'WGS84', 'parameter': 'Sulfur dioxide', 'sample_duration': '24-HR BLK AVG', 'pollutant_standard': 'SO2 24-hour 1971', 'date_local': '2020-01-13', 'units_of_measure': 'Parts per billion', 'event_type': 'None', 'observation_count': 1, 'observation_percent': 100.0, 'validity_indicator': 'Y', 'arithmetic_mean': 1.2, 'first_max_value': 1.2, 'first_max_hour': 23, 'aqi': None, 'method_code': '600', 'method': 'Instrumental - Ultraviolet Fluorescence API 100 EU', 'local_site_name': 'JLG SUPERSITE', 'site_address': '4530 N 17TH AVENUE', 'state': 'Arizona', 'county': 'Maricopa', 'city': 'Phoenix', 'cbsa_code': '38060', 'cbsa': 'Phoenix-Mesa-Scottsdale, AZ', 'date_of_last_change': '2020-04-09'}, {'state_code': '04', 'county_code': '013', 'site_number': '9997', 'parameter_code': '42401', 'poc': 1, 'latitude': 33.503833, 'longitude': -112.095767, 'datum': 'WGS84', 'parameter': 'Sulfur dioxide', 'sample_duration': '3-HR BLK AVG', 'pollutant_standard': 'SO2 3-hour 1971', 'date_local': '2020-01-13', 'units_of_measu ...
# -------------
# {'Header': [{'status': 'Success', 'request_time': '2020-04-12T14:22:33-04:00', 'url': 'https://aqs.epa.gov/data/api/dailyData/byBox?email=josephmrafferty@gmail.com&key=coppergazelle96&param=44201&bdate=20200113&edate=20200113&minlat=25.1&maxlat=49.3&minlon=-124.7&maxlon=-66.9', 'rows': 904}], 'Data': [{'state_code': '04', 'county_code': '013', 'site_number': '9997', 'parameter_code': '44201', 'poc': 1, 'latitude': 33.503833, 'longitude': -112.095767, 'datum': 'WGS84', 'parameter': 'Ozone', 'sample_duration': '1 HOUR', 'pollutant_standard': 'Ozone 1-hour 1979', 'date_local': '2020-01-13', 'units_of_measure': 'Parts per million', 'event_type': 'None', 'observation_count': 24, 'observation_percent': 100.0, 'validity_indicator': 'Y', 'arithmetic_mean': 0.013708, 'first_max_value': 0.04, 'first_max_hour': 15, 'aqi': None, 'method_code': '087', 'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION', 'local_site_name': 'JLG SUPERSITE', 'site_address': '4530 N 17TH AVENUE', 'state': 'Arizona', 'county': 'Maricopa', 'city': 'Phoenix', 'cbsa_code': '38060', 'cbsa': 'Phoenix-Mesa-Scottsdale, AZ', 'date_of_last_change': '2020-04-09'}, {'state_code': '04', 'county_code': '013', 'site_number': '9997', 'parameter_code': '44201', 'poc': 1, 'latitude': 33.503833, 'longitude': -112.095767, 'datum': 'WGS84', 'parameter': 'Ozone', 'sample_duration': '8-HR RUN AVG BEGIN HOUR', 'pollutant_standard': 'Ozone 8-Hour 1997', 'date_local': '2020-01-13', 'units_of_measure': 'Parts per million', 'event_type': 'None', 'observation_count': 24, 'observation_percent': 100.0, 'validity_indicator': 'Y', 'arithmetic_mean': 0.012458, 'first_max_value': 0.032, 'first_max_hour': 10, 'aqi': 30, 'method_code': '087', 'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION', 'local_site_name': 'JLG SUPERSITE', 'site_address': '4530 N 17TH AVENUE', 'state': 'Arizona', 'county': 'Maricopa', 'city': 'Phoenix', 'cbsa_code': '38060', 'cbsa': 'Phoenix-Mesa-Scottsdale, AZ', 'date_of_last_change': '2020-04-09'}, {'state_code': '04', 'county_code': '013', 'site_number': '9997', 'parameter_code': '44201', 'poc': 1, 'latitude': 33.503833, 'longitude': -112.095767, 'datum': 'WGS84', 'parameter': 'Ozone', 'sample_duration': '8-HR RUN AVG BEGIN HOUR', 'pollutant_standard': 'Ozone 8-Hour 2008', 'date_local': '2020-01-13', 'units_of_measure': 'Parts per million', 'event_type': 'None', 'observation_count': 24, 'observation_percent': 100.0, 'validity_indicator': 'Y', 'arithmetic_mean': 0.012458, 'first_max_value': 0.032, 'first_max_hour': 10, 'aqi': 30, 'method_code': '087', 'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION', 'local_site_name': 'JLG SUPERSITE', 'site_address': '4530 N 17TH AVENUE', 'state': 'Arizona', 'county': 'Maricopa', 'city': 'Phoenix', 'cbsa_code': '38060', 'cbsa': 'Phoenix-Mesa-Scottsdale, AZ', 'date_of_last_change': '2020-04-09'}, {'state_code': '04', 'county_code': '013', 'site_number': '9997', 'parameter_code': '44201', 'poc': 1, 'latitude': 33.503833, 'longitude': -112.095767, 'datum': 'WGS84', 'parameter': 'Ozone', 'sample_duration': '8-HR RUN AVG BEGIN HOUR', 'pollutant_standard': 'Ozone 8-hour 2015', 'date_local': '2020-01-13', 'units_of_measure': 'Parts per million', 'event_type': 'None', 'observation_count': 17, 'observation_percent': 100.0, 'validity_indicator': 'Y', 'arithmetic_mean': 0.013882, 'first_max_value': 0.032, 'first_max_hour': 10, 'aqi': 30, 'method_code': '087', 'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION', 'local_site_name': 'JLG SUPERSITE', 'site_address': '4530 N 17TH AVENUE', 'state': 'Arizona', 'county': 'Maricopa', 'city': 'Phoenix', 'cbsa_code': '38060', 'cbsa': 'Phoenix-Mesa-Scottsdale, AZ', 'date_of_last_change': '2020-04-09'}, {'state_code': '04', 'county_code': '025', 'site_number': '8034', 'parameter_code': '44201', 'poc': 3, 'latitude': 34.612055, 'longitude': -112.463213, 'datum': 'NAD83', 'parameter': 'Ozone', 'sample_duration': '1 HOUR', 'pollutant_standard': 'Ozone 1-hour 1979', 'date_local': '2020-01-13', 'units_of_measure': ' ...
# -------------
# {'Header': [{'status': 'Success', 'request_time': '2020-04-12T14:22:40-04:00', 'url': 'https://aqs.epa.gov/data/api/dailyData/byBox?email=josephmrafferty@gmail.com&key=coppergazelle96&param=81102&bdate=20200113&edate=20200113&minlat=25.1&maxlat=49.3&minlon=-124.7&maxlon=-66.9', 'rows': 190}], 'Data': [{'state_code': '04', 'county_code': '013', 'site_number': '9997', 'parameter_code': '81102', 'poc': 3, 'latitude': 33.503833, 'longitude': -112.095767, 'datum': 'WGS84', 'parameter': 'PM10 Total 0-10um STP', 'sample_duration': '1 HOUR', 'pollutant_standard': None, 'date_local': '2020-01-13', 'units_of_measure': 'Micrograms/cubic meter (25 C)', 'event_type': 'None', 'observation_count': 23, 'observation_percent': 96.0, 'validity_indicator': 'Y', 'arithmetic_mean': 34.695652, 'first_max_value': 63.0, 'first_max_hour': 8, 'aqi': None, 'method_code': '122', 'method': 'INSTRUMENT MET ONE 4 MODELS - BETA ATTENUATION', 'local_site_name': 'JLG SUPERSITE', 'site_address': '4530 N 17TH AVENUE', 'state': 'Arizona', 'county': 'Maricopa', 'city': 'Phoenix', 'cbsa_code': '38060', 'cbsa': 'Phoenix-Mesa-Scottsdale, AZ', 'date_of_last_change': '2020-04-09'}, {'state_code': '04', 'county_code': '013', 'site_number': '9997', 'parameter_code': '81102', 'poc': 3, 'latitude': 33.503833, 'longitude': -112.095767, 'datum': 'WGS84', 'parameter': 'PM10 Total 0-10um STP', 'sample_duration': '24-HR BLK AVG', 'pollutant_standard': 'PM10 24-hour 2006', 'date_local': '2020-01-13', 'units_of_measure': 'Micrograms/cubic meter (25 C)', 'event_type': 'None', 'observation_count': 1, 'observation_percent': 100.0, 'validity_indicator': 'Y', 'arithmetic_mean': 34.0, 'first_max_value': 34.0, 'first_max_hour': 23, 'aqi': 31, 'method_code': '122', 'method': 'INSTRUMENT MET ONE 4 MODELS - BETA ATTENUATION', 'local_site_name': 'JLG SUPERSITE', 'site_address': '4530 N 17TH AVENUE', 'state': 'Arizona', 'county': 'Maricopa', 'city': 'Phoenix', 'cbsa_code': '38060', 'cbsa': 'Phoenix-Mesa-Scottsdale, AZ', 'date_of_last_change': '2020-04-09'}, {'state_code': '04', 'county_code': '019', 'site_number': '0020', 'parameter_code': '81102', 'poc': 3, 'latitude': 32.414344, 'longitude': -111.154544, 'datum': 'WGS84', 'parameter': 'PM10 Total 0-10um STP', 'sample_duration': '1 HOUR', 'pollutant_standard': None, 'date_local': '2020-01-13', 'units_of_measure': 'Micrograms/cubic meter (25 C)', 'event_type': 'None', 'observation_count': 24, 'observation_percent': 100.0, 'validity_indicator': 'Y', 'arithmetic_mean': 31.583333, 'first_max_value': 53.0, 'first_max_hour': 9, 'aqi': None, 'method_code': '122', 'method': 'INSTRUMENT MET ONE 4 MODELS - BETA ATTENUATION', 'local_site_name': 'RILLITO', 'site_address': '8840 W ROBINSON STREET, RILLITO', 'state': 'Arizona', 'county': 'Pima', 'city': 'Rillito', 'cbsa_code': '46060', 'cbsa': 'Tucson, AZ', 'date_of_last_change': '2020-04-09'}, {'state_code': '04', 'county_code': '019', 'site_number': '0020', 'parameter_code': '81102', 'poc': 3, 'latitude': 32.414344, 'longitude': -111.154544, 'datum': 'WGS84', 'parameter': 'PM10 Total 0-10um STP', 'sample_duration': '24-HR BLK AVG', 'pollutant_standard': 'PM10 24-hour 2006', 'date_local': '2020-01-13', 'units_of_measure': 'Micrograms/cubic meter (25 C)', 'event_type': 'None', 'observation_count': 1, 'observation_percent': 100.0, 'validity_indicator': 'Y', 'arithmetic_mean': 31.0, 'first_max_value': 31.0, 'first_max_hour': 23, 'aqi': 29, 'method_code': '122', 'method': 'INSTRUMENT MET ONE 4 MODELS - BETA ATTENUATION', 'local_site_name': 'RILLITO', 'site_address': '8840 W ROBINSON STREET, RILLITO', 'state': 'Arizona', 'county': 'Pima', 'city': 'Rillito', 'cbsa_code': '46060', 'cbsa': 'Tucson, AZ', 'date_of_last_change': '2020-04-09'}, {'state_code': '04', 'county_code': '012', 'site_number': '8000', 'parameter_code': '81102', 'poc': 3, 'latitude': 34.2439, 'longitude': -113.5586, 'datum': 'NAD83', 'parameter': 'PM10 Total 0-10um STP', 'sample_duration': '1 HOUR', 'pollutant_standard': None, 'date_local': ' ...

# %%
print(response_list[4])
# Out:
# {'Header': [{'status': 'Success', 'request_time': '2020-04-12T14:22:46-04:00', 'url': 'https://aqs.epa.gov/data/api/dailyData/byBox?email=josephmrafferty@gmail.com&key=coppergazelle96&param=88101&bdate=20200113&edate=20200113&minlat=25.1&maxlat=49.3&minlon=-124.7&maxlon=-66.9', 'rows': 1582}], 'Data': [{'state_code': '04', 'county_code': '013', 'site_number': '9997', 'parameter_code': '88101', 'poc': 3, 'latitude': 33.503833, 'longitude': -112.095767, 'datum': 'WGS84', 'parameter': 'PM2.5 - Local Conditions', 'sample_duration': '1 HOUR', 'pollutant_standard': None, 'date_local': '2020-01-13', 'units_of_measure': 'Micrograms/cubic meter (LC)', 'event_type': 'None', 'observation_count': 23, 'observation_percent': 96.0, 'validity_indicator': 'Y', 'arithmetic_mean': 13.695652, 'first_max_value': 28.0, 'first_max_hour': 22, 'aqi': None, 'method_code': '170', 'method': 'Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation', 'local_site_name': 'JLG SUPERSITE', 'site_address': '4530 N 17TH AVENUE', 'state': 'Arizona', 'county': 'Maricopa', 'city': 'Phoenix', 'cbsa_code': '38060', 'cbsa': 'Phoenix-Mesa-Scottsdale, AZ', 'date_of_last_change': '2020-04-09'}, {'state_code': '04', 'county_code': '013', 'site_number': '9997', 'parameter_code': '88101', 'poc': 3, 'latitude': 33.503833, 'longitude': -112.095767, 'datum': 'WGS84', 'parameter': 'PM2.5 - Local Conditions', 'sample_duration': '24-HR BLK AVG', 'pollutant_standard': 'PM25 24-hour 2006', 'date_local': '2020-01-13', 'units_of_measure': 'Micrograms/cubic meter (LC)', 'event_type': 'None', 'observation_count': 1, 'observation_percent': 100.0, 'validity_indicator': 'Y', 'arithmetic_mean': 13.6, 'first_max_value': 13.6, 'first_max_hour': 0, 'aqi': 54, 'method_code': '170', 'method': 'Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation', 'local_site_name': 'JLG SUPERSITE', 'site_address': '4530 N 17TH AVENUE', 'state': 'Arizona', 'county': 'Maricopa', 'city': 'Phoenix', 'cbsa_code': '38060', 'cbsa': 'Phoenix-Mesa-Scottsdale, AZ', 'date_of_last_change': '2020-04-09'}, {'state_code': '04', 'county_code': '013', 'site_number': '9997', 'parameter_code': '88101', 'poc': 3, 'latitude': 33.503833, 'longitude': -112.095767, 'datum': 'WGS84', 'parameter': 'PM2.5 - Local Conditions', 'sample_duration': '24-HR BLK AVG', 'pollutant_standard': 'PM25 Annual 2006', 'date_local': '2020-01-13', 'units_of_measure': 'Micrograms/cubic meter (LC)', 'event_type': 'None', 'observation_count': 1, 'observation_percent': 100.0, 'validity_indicator': 'Y', 'arithmetic_mean': 13.6, 'first_max_value': 13.6, 'first_max_hour': 0, 'aqi': 54, 'method_code': '170', 'method': 'Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation', 'local_site_name': 'JLG SUPERSITE', 'site_address': '4530 N 17TH AVENUE', 'state': 'Arizona', 'county': 'Maricopa', 'city': 'Phoenix', 'cbsa_code': '38060', 'cbsa': 'Phoenix-Mesa-Scottsdale, AZ', 'date_of_last_change': '2020-04-09'}, {'state_code': '04', 'county_code': '013', 'site_number': '9997', 'parameter_code': '88101', 'poc': 3, 'latitude': 33.503833, 'longitude': -112.095767, 'datum': 'WGS84', 'parameter': 'PM2.5 - Local Conditions', 'sample_duration': '24-HR BLK AVG', 'pollutant_standard': 'PM25 24-hour 2012', 'date_local': '2020-01-13', 'units_of_measure': 'Micrograms/cubic meter (LC)', 'event_type': 'None', 'observation_count': 1, 'observation_percent': 100.0, 'validity_indicator': 'Y', 'arithmetic_mean': 13.6, 'first_max_value': 13.6, 'first_max_hour': 0, 'aqi': 54, 'method_code': '170', 'method': 'Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation', 'local_site_name': 'JLG SUPERSITE', 'site_address': '4530 N 17TH AVENUE', 'state': 'Arizona', 'county': 'Maricopa', 'city': 'Phoenix', 'cbsa_code': '38060', 'cbsa': 'Phoenix-Mesa-Scottsdale, AZ', 'date_of_last_change': '2020-04-09'}, {'state_code': '04', 'county_code': '013', 'site_number': '9997', 'parameter_code': '88101', 'poc': 3, 'latitude': 33.503833, 'longitude': -112.095767, 'datum': 'WGS84', 'parameter': 'PM2.5 - Loc ...

# %%
#hard coded date for 01/01/2020 (20200101), all 5 params and the API key

#query_url = f"https://aqs.epa.gov/data/api/dailyData/byBox?email=josephmrafferty@gmail.com&key=coppergazelle96&param=42101&bdate=20200101&edate=20200101&minlat=25.1&maxlat=49.3&minlon=-124.7&maxlon=-66.9"

#response = requests.get(query_url).json()
#print(response)

# %%
#response = requests.get(query_urlList[0]).json()
#print(response)

# %%
#for url in tqdm(query_urlList):
    
    #try:
        #response = requests.get(url).json()
        
    #except:
        #errorCount+=1
        
    #print(response)
    #print('-----------------')
    #Wait a second in loop to not over exceed rate limit of API
    #time.sleep(5)
